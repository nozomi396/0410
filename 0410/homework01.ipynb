# %%
import requests

# %%
response = requests.get("http://www.novelscape.net/wxxs/j/jingyong/ffwz/001.htm")

# %%
response.encoding = "big5"

# %%
book1 = response.text

# %%
print(book1)
# Out:
# <HTML><HEAD><meta http-equiv="Content-Type" content="text/html; charset=big5"><TITLE>金庸-->飛狐外傳-->第一章　大雨商家堡</TITLE>
# <META NAME="keywords" CONTENT="金庸 飛狐外傳 第一章　大雨商家堡">
# <META NAME="description" CONTENT="金庸 - 飛狐外傳 - 第一章　大雨商家堡">
#
# <style>
# <!--
# #page {position:absolute; z-index:0; left:0px; top:0px}
# .tt3 {font: 9pt/12pt "宋体"}
# .tt2 {font: 12pt/15pt "宋体"}
# a {text-decoration:none}
# a:hover {color: blue;text-decoration:underline}
# -->
# </style>
# </HEAD>
# <body text="#000000" link="#0000EE" vlink="#0000EE" alink="#FF0000" bgcolor="#F1F1F3" leftmargin="3" topmargin="3" marginheight="3" marginwidth="3">
# <center><table WIDTH="720" >
# <tr ALIGN=CENTER>
# <td WIDTH="100%">
# <center><table BORDER=0 CELLSPACING=0 CELLPADDING=0 >
# <tr>
# <td><script src="../../../../ad/text01.js"></script>
# </td>
# </tr>
# </table></center>
# </td>
# </tr>
# </table></center>
# <TABLE WIDTH="100%" CELLPADDING=10 CELLSPACING=0 BORDER=0>
# <TR>
# ...

# %%
book1[:]
# Out:
# '<HTML><HEAD><meta http-equiv="Content-Type" content="text/html; charset=big5"><TITLE>金庸-->飛狐外傳-->第一章\u3000大雨商家堡</TITLE>\r\n<META NAME="keywords" CONTENT="金庸 飛狐外傳 第一章\u3000大雨商家堡">\r\n<META NAME="description" CONTENT="金庸 - 飛狐外傳 - 第一章\u3000大雨商家堡">\r\n\r\n<style>\r\n<!--\r\n#page {position:absolute; z-index:0; left:0px; top:0px}\r\n.tt3 {font: 9pt/12pt "宋体"}\r\n.tt2 {font: 12pt/15pt "宋体"}\r\na {text-decoration:none}\r\na:hover {color: blue;text-decoration:underline}\r\n-->\r\n</style>\r\n</HEAD>\r\n<body text="#000000" link="#0000EE" vlink="#0000EE" alink="#FF0000" bgcolor="#F1F1F3" leftmargin="3" topmargin="3" marginheight="3" marginwidth="3">\r\n<center><table WIDTH="720" >\r\n<tr ALIGN=CENTER>\r\n<td WIDTH="100%">\r\n<center><table BORDER=0 CELLSPACING=0 CELLPADDING=0 >\r\n<tr>\r\n<td><script src="../../../../ad/text01.js"></script>\r\n</td>\r\n</tr>\r\n</table></center>\r\n</td>\r\n</tr>\r\n</table></center>\r\n<TABLE WIDTH="100%" CELLPADDING=10 CELLSPACING=0 BORDER=0>\r\n<TR>\r\n<T
# ...

# %%
book1[250:]
# Out:
# '{position:absolute; z-index:0; left:0px; top:0px}\r\n.tt3 {font: 9pt/12pt "宋体"}\r\n.tt2 {font: 12pt/15pt "宋体"}\r\na {text-decoration:none}\r\na:hover {color: blue;text-decoration:underline}\r\n-->\r\n</style>\r\n</HEAD>\r\n<body text="#000000" link="#0000EE" vlink="#0000EE" alink="#FF0000" bgcolor="#F1F1F3" leftmargin="3" topmargin="3" marginheight="3" marginwidth="3">\r\n<center><table WIDTH="720" >\r\n<tr ALIGN=CENTER>\r\n<td WIDTH="100%">\r\n<center><table BORDER=0 CELLSPACING=0 CELLPADDING=0 >\r\n<tr>\r\n<td><script src="../../../../ad/text01.js"></script>\r\n</td>\r\n</tr>\r\n</table></center>\r\n</td>\r\n</tr>\r\n</table></center>\r\n<TABLE WIDTH="100%" CELLPADDING=10 CELLSPACING=0 BORDER=0>\r\n<TR>\r\n<TD CLASS="tt3" VALIGN="top" width="8%"  bgcolor="#F1F1F3"><strong><A HREF="002.htm" >后一頁</A><BR>\r\n<A HREF="index.html" >前一頁</A><BR><A HREF="index.html" >回目錄</A><BR>\r\n</strong>\r\n</TD>\r\n<TD class="tt2" bgcolor="#F1F1F3" width="84%"><center><B><FONT style="FONT-SIZE: 12pt"
# ...

# %%
book1[1200:1300]
# Out:
# '"#FF5555">第一章\u3000大雨商家堡</B></center></FONT>\r\n<hr color="#EE9B73" size="1" width="94%">\r\n<BR>\r\n\u3000\u3000“胡一刀，曲池，'

# %%
book1[:100]
# Out:
# '<HTML><HEAD><meta http-equiv="Content-Type" content="text/html; charset=big5"><TITLE>金庸-->飛狐外傳-->第一章'

# %%
book1[2000:3000:5]
# Out:
# '漢急向。聲是見女么自了准不”：鏢？上什、”：點不么咱去<\n女年圓臉黑兩周股的漢眼女歲豪滿，有但，，勃<\n穿雨，臉珠出臉紅臉，嬌子著得女，雨笠都衣子神覺噗輕：”。R\u3000生堆多圍旁淋物身藍有著一趟夫著打。進正衣到人不都\r>那烤中個的一才到說人來健微身尺炯有了話皺責去！家豈沒少頭“陪出這八。道你，瞧啦<\n女笑親話頭想人外親親，，箭然那一總容沒則而還父，，中比更百<\n女有适看，脾胜肯道那也，偷老，你怎說意”'

# %%
book1[:100:3]
# Out:
# '<M<A<thpqvCtty"oe=e/m aeb5<T>-飛傳>章'

# %%
book1[2000::10]
# Out:
# '漢向聲見么了不：？什”點么去\n年臉兩股漢女豪，但，<穿，珠臉臉嬌著女雨都子覺輕”R生多旁物藍著趟著。正到不\r那中的才說來微尺有話責！豈少“出八道，啦\n笑話想外親，然一容則還，中更<女适，胜道也偷，怎意笑胜呢\n不女很。得到的這兩著黃翅了神！\u3000名作女花俗人什跟的錚。\u3000，著气。，了怒地就眼起著>三一一：似還官\r徐，”“錯”家正“你子\n便空。得你行官話？來瞪坐又無目\r馬要來怎個然光震，廳了地R听這得”“吧\n了玉負八十眉色得一。婦，子神婚捆，十人頭金有圓心帶出即，道混這B見目大穿到不取走子你衫婦，乎子一馬到\n個現在，和最我道”睛步起\n錚一院眼睛位十旁出那R到來笑”你“徐父地那沒，己毆子好道遠了\r兩沒回那秀年借過，”道”在過廳奇我武武喜，人B婆，那刀外石下樁“只是道，名，名？叫鏢馬瞪听知<震仰武侍道大大大豪的侍領等黃的漢何最所是不R道做的管向怕思你還么一在下頂足，<豪”式，拳也原”指洪北拳得。常道上錚太武知。\u3000向盤，出見一，使右扑及似人感：”\u3000拳寶腳何顯\n到笑。豪女又更突弓，拳步，旁叫B回子，他身和此聲師時出>一女是而已劈以斗鋒攻官尋般那道恨\r當肯會皺B凝，步一刀救盯他向眼身手刀，他手出扭\r何來臉徐，眼臉\n寶，會道好明”怎震獨純和。其何面抹爭，”\u3000，但明輸望出轟雷思這\n雖是火開了來說人斜\n行懶視，啦，鏢進步否久顫人空師招你掌胜。之實几。其\r馬謝年明异么是道呢徐胡。打前憑的起不護楞”\u3000：院震招劈用。一<抱師。意商你止。，談練商，上才他著，。\u3000，之說口三寬出門說道是>“三：了一。也意輕\n錚也拳什你結喜有，見，使\n路但，華卻徐他月了，藝。見，你\n告火之的刀，，目個黃襤\n一馬“沉么，“的拳馬你點家，他，馬父>奇商練父下想。低不五過了人說。半鳴里家避你？\u3000見八一快家淡。”年就劍奇提一來你”：再憑得問他少人兩B大刀B素地到得了言鳴刀商為那等道我年一死“睜一得“佛天鳳將是一得大來\u3000与聲強露年坐，R奔但匹<空，。音儿回伙這登的躍五將。，爹行道“上說R，接色，。想空：行望發\u3000開穿是縮极了而尖子飛密了對突，馬<空說，大”\u3000听藏到戴耀手，，。姓百\r馬，在名暗么這R一一“，吃寨五賞著對五\r果，鏢。區內：么道？湖有朋今邊幸。咐是生鏢取頭朋取就
# ...

# %%
book1[::100]
# Out:
# '<\u3000=\nb#=ErN2<"天\n是胡少手上漢”女臉R正微八，女笑的名。就還正行\r廳\n。頭混走到”位你子秀廳，道听大最怕，指太一”。，此已道步刀徐明面望開，空。道不用止著出一你但。，沉，下。八奇問地等“\u3000但這道想縮突听百一五道是牆手步，\n基，砰\u3000點腳實命個尺与個就的\n腿，這B見數：，叫閻招，忽“万丰了親施喘紛寶下說盜井田下“分，是，，，嬰作依站見，從實落沉是、美靜t<AsAa'

# %%
"JOJO's bizzare adventure"
# Out:
# "JOJO's bizzare adventure"

# %%
x = "\"JOJO's\" \nbizzare \tadventure" + " yo"*3
print(x)
# Out:
# "JOJO's"
# bizzare 	adventure yo yo yo

# %%
x[-5]
# Out:
# 'y'

# %%
y = x.split()
print(y)
# Out:
# ['"JOJO\'s"', 'bizzare', 'adventure', 'yo', 'yo', 'yo']

# %%
book1.split('，')
# Out:
# ['<HTML><HEAD><meta http-equiv="Content-Type" content="text/html; charset=big5"><TITLE>金庸-->飛狐外傳-->第一章\u3000大雨商家堡</TITLE>\r\n<META NAME="keywords" CONTENT="金庸 飛狐外傳 第一章\u3000大雨商家堡">\r\n<META NAME="description" CONTENT="金庸 - 飛狐外傳 - 第一章\u3000大雨商家堡">\r\n\r\n<style>\r\n<!--\r\n#page {position:absolute; z-index:0; left:0px; top:0px}\r\n.tt3 {font: 9pt/12pt "宋体"}\r\n.tt2 {font: 12pt/15pt "宋体"}\r\na {text-decoration:none}\r\na:hover {color: blue;text-decoration:underline}\r\n-->\r\n</style>\r\n</HEAD>\r\n<body text="#000000" link="#0000EE" vlink="#0000EE" alink="#FF0000" bgcolor="#F1F1F3" leftmargin="3" topmargin="3" marginheight="3" marginwidth="3">\r\n<center><table WIDTH="720" >\r\n<tr ALIGN=CENTER>\r\n<td WIDTH="100%">\r\n<center><table BORDER=0 CELLSPACING=0 CELLPADDING=0 >\r\n<tr>\r\n<td><script src="../../../../ad/text01.js"></script>\r\n</td>\r\n</tr>\r\n</table></center>\r\n</td>\r\n</tr>\r\n</table></center>\r\n<TABLE WIDTH="100%" CELLPADDING=10 CELLSPACING=0 BORDER=0>\r\n<TR>\r\n<
# ...

# %%
z = ' '.join(y)
print(z)
# Out:
# "JOJO's" bizzare adventure yo yo yo

# %%
z.startswith('JOJO')
# Out:
# False

# %%
z.find('yo')
# Out:
# 27

# %%
z.rfind('yo')
# Out:
# 33

# %%
book1.count("勃")
# Out:
# 3

# %%
z.strip('"')
# Out:
# 'JOJO\'s" bizzare adventure yo yo yo'

# %%
z.lower()
# Out:
# '"jojo\'s" bizzare adventure yo yo yo'

# %%
book1.replace('，','大雕')
# Out:
# '<HTML><HEAD><meta http-equiv="Content-Type" content="text/html; charset=big5"><TITLE>金庸-->飛狐外傳-->第一章\u3000大雨商家堡</TITLE>\r\n<META NAME="keywords" CONTENT="金庸 飛狐外傳 第一章\u3000大雨商家堡">\r\n<META NAME="description" CONTENT="金庸 - 飛狐外傳 - 第一章\u3000大雨商家堡">\r\n\r\n<style>\r\n<!--\r\n#page {position:absolute; z-index:0; left:0px; top:0px}\r\n.tt3 {font: 9pt/12pt "宋体"}\r\n.tt2 {font: 12pt/15pt "宋体"}\r\na {text-decoration:none}\r\na:hover {color: blue;text-decoration:underline}\r\n-->\r\n</style>\r\n</HEAD>\r\n<body text="#000000" link="#0000EE" vlink="#0000EE" alink="#FF0000" bgcolor="#F1F1F3" leftmargin="3" topmargin="3" marginheight="3" marginwidth="3">\r\n<center><table WIDTH="720" >\r\n<tr ALIGN=CENTER>\r\n<td WIDTH="100%">\r\n<center><table BORDER=0 CELLSPACING=0 CELLPADDING=0 >\r\n<tr>\r\n<td><script src="../../../../ad/text01.js"></script>\r\n</td>\r\n</tr>\r\n</table></center>\r\n</td>\r\n</tr>\r\n</table></center>\r\n<TABLE WIDTH="100%" CELLPADDING=10 CELLSPACING=0 BORDER=0>\r\n<TR>\r\n<T
# ...
